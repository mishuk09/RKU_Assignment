# %%
 import tkinter as tk

class AttendanceGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.root.title("Attendance")

        # Create the student labels
        self.student_labels = []
        for i in range(10):
            label = tk.Label(self.root, text=f"Student {i+1}")
            label.grid(row=i, column=0, padx=10, pady=10)
            self.student_labels.append(label)

        # Create the tick mark buttons
        self.tick_buttons = []
        for i in range(10):
            tick_var = tk.BooleanVar()
            button = tk.Checkbutton(self.root, variable=tick_var)
            button.grid(row=i, column=1)
            self.tick_buttons.append(tick_var)

        # Create the submit button
        submit_button = tk.Button(self.root, text="Submit", command=self.submit_attendance)
        submit_button.grid(row=10, column=0, columnspan=2, padx=10, pady=10)

    def submit_attendance(self):
        # Print the attendance for each student
        for i in range(10):
            attendance = "Present" if self.tick_buttons[i].get() else "Absent"
            print(f"Student {i+1}: {attendance}")

if __name__ == "__main__":
    app = AttendanceGUI()
    app.root.mainloop()

# %%
import tkinter as tk

class AttendanceGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.root.title("Attendance")

        # Create the headers for roll, name, and attendance
        roll_label = tk.Label(self.root, text="Roll")
        roll_label.grid(row=0, column=0, padx=10, pady=10)

        name_label = tk.Label(self.root, text="Name")
        name_label.grid(row=0, column=1, padx=10, pady=10)

        attendance_label = tk.Label(self.root, text="Attendance")
        attendance_label.grid(row=0, column=2, padx=10, pady=10)

        # Create the student labels, roll numbers, and tick mark buttons
        self.student_labels = []
        self.roll_labels = []
        self.tick_buttons = []
        for i in range(10):
            roll = i+1
            roll_label = tk.Label(self.root, text=roll)
            roll_label.grid(row=i+1, column=0, padx=10, pady=10)
            self.roll_labels.append(roll_label)

            name_label = tk.Label(self.root, text=f"Student {i+1}")
            name_label.grid(row=i+1, column=1, padx=10, pady=10)
            self.student_labels.append(name_label)

            tick_var = tk.BooleanVar()
            button = tk.Checkbutton(self.root, variable=tick_var)
            button.grid(row=i+1, column=2)
            self.tick_buttons.append(tick_var)

        # Create the submit button
        submit_button = tk.Button(self.root, text="Submit", command=self.submit_attendance)
        submit_button.grid(row=11, column=0, columnspan=3, padx=10, pady=10)

    def submit_attendance(self):
        # Print the attendance for each student
        for i in range(10):
            roll = i+1
            name = self.student_labels[i]["text"]
            attendance = "Present" if self.tick_buttons[i].get() else "Absent"
            print(f"{roll}\t{name}\t{attendance}")

if __name__ == "__main__":
    app = AttendanceGUI()
    app.root.mainloop()

# %%
import tkinter as tk

class AttendanceGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.root.title("RKU Attendance System")
        

        # Create the welcome label
        welcome_label = tk.Label(self.root, text="Welcome to RKU Server", font=("Arial", 14))
        welcome_label.grid(row=0, column=0, columnspan=3, pady=10)

        # Create the headers for roll, name, and attendance
        roll_label = tk.Label(self.root, text="Roll")
        roll_label.grid(row=1, column=0, padx=10, pady=10)

        name_label = tk.Label(self.root, text="Name")
        name_label.grid(row=1, column=1, padx=10, pady=10)

        attendance_label = tk.Label(self.root, text="Attendance")
        attendance_label.grid(row=1, column=2, padx=10, pady=10)

        # Create the student labels, roll numbers, and tick mark buttons
        self.student_labels = []
        self.roll_labels = []
        self.tick_buttons = []
        for i in range(10):
            roll = i+1
            roll_label = tk.Label(self.root, text=roll)
            roll_label.grid(row=i+2, column=0, padx=10, pady=10)
            self.roll_labels.append(roll_label)

            name_label = tk.Label(self.root, text=f"Student {i+1}")
            name_label.grid(row=i+2, column=1, padx=10, pady=10)
            self.student_labels.append(name_label)

            tick_var = tk.BooleanVar()
            button = tk.Checkbutton(self.root, variable=tick_var)
            button.grid(row=i+2, column=2)
            self.tick_buttons.append(tick_var)

        # Create the submit button
        submit_button = tk.Button(self.root, text="Submit", command=self.submit_attendance)
        submit_button.grid(row=13, column=0, columnspan=3, padx=10, pady=10)

    def submit_attendance(self):
        # Print the attendance for each student
        for i in range(10):
            roll = i+1
            name = self.student_labels[i]["text"]
            attendance = "Present" if self.tick_buttons[i].get() else "Absent"
            print(f"{roll}\t{name}\t{attendance}")

if __name__ == "__main__":
    app = AttendanceGUI()
    app.root.mainloop()

# %%
import tkinter as tk


class AttendanceGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.root.title("RKU Attendance System")

        # Create the welcome label
        welcome_label = tk.Label(self.root, text="Welcome to RKU Server", font=("Arial", 14))
        welcome_label.grid(row=0, column=0, columnspan=3, pady=10)

        # Create input fields for faculty, division, and date
        faculty_label = tk.Label(self.root, text="Faculty:")
        faculty_label.grid(row=1, column=0, padx=10, pady=10, sticky="w")
        self.faculty_entry = tk.Entry(self.root)
        self.faculty_entry.grid(row=1, column=1, padx=10, pady=10)

        division_label = tk.Label(self.root, text="Division:")
        division_label.grid(row=2, column=0, padx=10, pady=10, sticky="w")
        self.division_entry = tk.Entry(self.root)
        self.division_entry.grid(row=2, column=1, padx=10, pady=10)

        date_label = tk.Label(self.root, text="Date:")
        date_label.grid(row=3, column=0, padx=10, pady=10, sticky="w")
        self.date_entry = tk.Entry(self.root)
        self.date_entry.grid(row=3, column=1, padx=10, pady=10)

        # Create the headers for roll, name, and attendance
        roll_label = tk.Label(self.root, text="Roll")
        roll_label.grid(row=4, column=0, padx=10, pady=10)

        name_label = tk.Label(self.root, text="Name")
        name_label.grid(row=4, column=1, padx=10, pady=10)

        attendance_label = tk.Label(self.root, text="Attendance")
        attendance_label.grid(row=4, column=2, padx=10, pady=10)

        # Create the student labels, roll numbers, and tick mark buttons
        self.student_labels = []
        self.roll_labels = []
        self.tick_buttons = []
        for i in range(10):
            roll = i+1
            roll_label = tk.Label(self.root, text=roll)
            roll_label.grid(row=i+5, column=0, padx=10, pady=10)
            self.roll_labels.append(roll_label)

            name_label = tk.Label(self.root, text=f"Student {i+1}")
            name_label.grid(row=i+5, column=1, padx=10, pady=10)
            self.student_labels.append(name_label)

            tick_var = tk.BooleanVar()
            button = tk.Checkbutton(self.root, variable=tick_var)
            button.grid(row=i+5, column=2)
            self.tick_buttons.append(tick_var)

        # Create the submit button
        submit_button = tk.Button(self.root, text="Submit", command=self.submit_attendance)
        submit_button.grid(row=16, column=0, columnspan=3, padx=10, pady=10)

    def submit_attendance(self):
        # Print the attendance for each student
        faculty = self.faculty_entry.get()
        division = self.division_entry.get()
        date = self.date_entry.get()
        print(f"Faculty: {faculty}")
        print(f"Division: {division}")
        print(f"Date: {date}")
if __name__ == "__main__":
    app = AttendanceGUI()
    app.root.mainloop()
# Out:
# Faculty: fda
# Division: adfa
# Date: 12-12-1111
# Faculty: fda
# Division: adfa
# Date: 12-12-1111

# %%
import tkinter as tk
import mysql.connector

# Create a connection to the database
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="rku_attendence_admin"
)

# Create a cursor object to execute SQL queries
mycursor = mydb.cursor()

# Create a table if it does not already exist
mycursor.execute("CREATE TABLE IF NOT EXISTS attendance (id INT AUTO_INCREMENT PRIMARY KEY, faculty VARCHAR(255), division VARCHAR(255), date VARCHAR(255), student_name VARCHAR(255), attendance_status VARCHAR(255))")

class AttendanceGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.root.title("RKU Attendance System")

        # Create the welcome label
        welcome_label = tk.Label(self.root, text="Welcome to RKU Server", font=("Arial", 14))
        welcome_label.grid(row=0, column=0, columnspan=3, pady=10)

        # Create input fields for faculty, division, and date
        faculty_label = tk.Label(self.root, text="Faculty:")
        faculty_label.grid(row=1, column=0, padx=10, pady=10, sticky="w")
        self.faculty_entry = tk.Entry(self.root)
        self.faculty_entry.grid(row=1, column=1, padx=10, pady=10)

        division_label = tk.Label(self.root, text="Division:")
        division_label.grid(row=2, column=0, padx=10, pady=10, sticky="w")
        self.division_entry = tk.Entry(self.root)
        self.division_entry.grid(row=2, column=1, padx=10, pady=10)

        date_label = tk.Label(self.root, text="Date:")
        date_label.grid(row=3, column=0, padx=10, pady=10, sticky="w")
        self.date_entry = tk.Entry(self.root)
        self.date_entry.grid(row=3, column=1, padx=10, pady=10)

        # Create the headers for roll, name, and attendance
        roll_label = tk.Label(self.root, text="Roll")
        roll_label.grid(row=4, column=0, padx=10, pady=10)

        name_label = tk.Label(self.root, text="Name")
        name_label.grid(row=4, column=1, padx=10, pady=10)

        attendance_label = tk.Label(self.root, text="Attendance")
        attendance_label.grid(row=4, column=2, padx=10, pady=10)

        # Create the student labels, roll numbers, and tick mark buttons
        self.student_labels = []
        self.roll_labels = []
        self.tick_buttons = []
        for i in range(10):
            roll = i+1
            roll_label = tk.Label(self.root, text=roll)
            roll_label.grid(row=i+5, column=0, padx=10, pady=10)
            self.roll_labels.append(roll_label)

            name_label = tk.Label(self.root, text=f"Student {i+1}")
            name_label.grid(row=i+5, column=1, padx=10, pady=10)
            self.student_labels.append(name_label)

            tick_var = tk.BooleanVar()
            button = tk.Checkbutton(self.root, variable=tick_var)
            button.grid(row=i+5, column=2)
            self.tick_buttons.append(tick_var)

        # Create the submit button
        submit_button = tk.Button(self.root, text="Submit", command=self.submit_attendance)
        submit_button.grid(row=16, column=0, columnspan=3, padx=10, pady=10)
 

    def submit_attendance(self):
        # Get the attendance data from the input fields and tick marks
        faculty = self.faculty_entry.get()
        division = self.division_entry.get()
        date = self.date_entry.get()
        attendance_data = []
        for i, tick_var in enumerate(self.tick_buttons):
            roll = i+1
            name = self.student_labels[i].cget("text")
            attendance_status = "Present" if tick_var.get() else "Absent"
            attendance_data.append((faculty, division, date, name, attendance_status))
    
        # Insert the attendance data into the database
        sql = "INSERT INTO attendance (faculty, division, date, student_name, attendance_status) VALUES (%s, %s, %s, %s, %s)"
        mycursor.executemany(sql, attendance_data)
        mydb.commit()
    
        # Show a message in the GUI interface
        message_label = tk.Label(self.root, text="Attendance data inserted successfully", fg="green")
        message_label.grid(row=17, column=0, columnspan=3, pady=10) 

if __name__ == "__main__":
    app = AttendanceGUI()
    app.root.mainloop()

# %%
import tkinter as tk
import mysql.connector

# Create a connection to the database
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="rku_attendence_admin"
)

# Create a cursor object to execute SQL queries
mycursor = mydb.cursor()

# Create a table if it does not already exist
mycursor.execute("CREATE TABLE IF NOT EXISTS attendance (id INT AUTO_INCREMENT PRIMARY KEY, faculty VARCHAR(255), division VARCHAR(255), date VARCHAR(255), student_name VARCHAR(255), attendance_status VARCHAR(255))")

class AttendanceGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.root.title("RKU Attendance System")

        # Create the welcome label
        welcome_label = tk.Label(self.root, text="Welcome to RKU Server", font=("Arial", 14))
        welcome_label.grid(row=0, column=0, columnspan=3, pady=10)

        # Create input fields for faculty, division, and date
        faculty_label = tk.Label(self.root, text="Faculty:")
        faculty_label.grid(row=1, column=0, padx=10, pady=10, sticky="w")
        self.faculty_entry = tk.Entry(self.root)
        self.faculty_entry.grid(row=1, column=1, padx=10, pady=10)

        division_label = tk.Label(self.root, text="Division:")
        division_label.grid(row=2, column=0, padx=10, pady=10, sticky="w")
        self.division_entry = tk.Entry(self.root)
        self.division_entry.grid(row=2, column=1, padx=10, pady=10)

        date_label = tk.Label(self.root, text="Date:")
        date_label.grid(row=3, column=0, padx=10, pady=10, sticky="w")
        self.date_entry = tk.Entry(self.root)
        self.date_entry.grid(row=3, column=1, padx=10, pady=10)

        # Create the headers for roll, name, and attendance
        roll_label = tk.Label(self.root, text="Roll")
        roll_label.grid(row=4, column=0, padx=10, pady=10)

        name_label = tk.Label(self.root, text="Name")
        name_label.grid(row=4, column=1, padx=10, pady=10)

        attendance_label = tk.Label(self.root, text="Attendance")
        attendance_label.grid(row=4, column=2, padx=10, pady=10)

        # Create the student labels, roll numbers, and tick mark buttons
        self.student_labels = []
        self.roll_labels = []
        self.tick_buttons = []
        for i in range(10):
            roll = i+1
            roll_label = tk.Label(self.root, text=roll)
            roll_label.grid(row=i+5, column=0, padx=10, pady=10)
            self.roll_labels.append(roll_label)

            name_label = tk.Label(self.root, text=f"Student {i+1}")
            name_label.grid(row=i+5, column=1, padx=10, pady=10)
            self.student_labels.append(name_label)

            tick_var = tk.BooleanVar()
            button = tk.Checkbutton(self.root, variable=tick_var)
            button.grid(row=i+5, column=2)
            self.tick_buttons.append(tick_var)

        # Create the submit button
        submit_button = tk.Button(self.root, text="Submit", command=self.submit_attendance)
        submit_button.grid(row=16, column=0, columnspan=3, padx=10, pady=10)

        # Create the show data button
        show_data_button = tk.Button(self.root, text="Show Attendance Data", command=self.show_attendance_data)
        show_data_button.grid(row=18, column=0, columnspan=3, padx=10, pady=10)

    def show_attendance_data(self):
        # Query the attendance data from the database
        mycursor.execute("SELECT * FROM attendance")
        attendance_data = mycursor.fetchall()

        # Create a new window to show the attendance data
        data_window = tk.Toplevel(self.root)
        data_window.title("Attendance Data")
    
        # Create a table to display the attendance data
        table = tk.Frame(data_window)
        table.pack(padx=10, pady=10)
        
        # Create headers for the table
        headers = ["ID", "Faculty", "Division", "Date", "Name", "Attendance Status"]
        for i, header in enumerate(headers):
            label = tk.Label(table, text=header, font=("Arial", 12, "bold"), padx=10, pady=10, borderwidth=1, relief="solid")
            label.grid(row=0, column=i)
    
        # Add the attendance data to the table
        for i, row in enumerate(attendance_data):
            for j, item in enumerate(row):
                label = tk.Label(table, text=item, font=("Arial", 12), padx=10, pady=10, borderwidth=1, relief="solid")
                label.grid(row=i+1, column=j)

    def submit_attendance(self):
        # Get the attendance data from the input fields and tick marks
        faculty = self.faculty_entry.get()
        division = self.division_entry.get()
        date = self.date_entry.get()
        attendance_data = []
        for i, tick_var in enumerate(self.tick_buttons):
            roll = i+1
            name = self.student_labels[i].cget("text")
            attendance_status = "Present" if tick_var.get() else "Absent"
            attendance_data.append((faculty, division, date, name, attendance_status))
    
        # Insert the attendance data into the database
        sql = "INSERT INTO attendance (faculty, division, date, student_name, attendance_status) VALUES (%s, %s, %s, %s, %s)"
        mycursor.executemany(sql, attendance_data)
        mydb.commit()
    
        # Show a message in the GUI interface
        message_label = tk.Label(self.root, text="Attendance data inserted successfully", fg="green")
        message_label.grid(row=17, column=0, columnspan=3, pady=10) 

if __name__ == "__main__":
    app = AttendanceGUI()
    app.root.mainloop()

# %%
import tkinter as tk

# Create the main window
root = tk.Tk()
root.title("RKU Student Attendance System")

# Define the labels
label_name = tk.Label(root, text="Name")
label_roll_no = tk.Label(root, text="Roll No.")
label_attendance = tk.Label(root, text="Attendance")

# Define the entry boxes
entry_name = tk.Entry(root)
entry_roll_no = tk.Entry(root)
entry_attendance = tk.Entry(root)

# Define the submit button
def submit():
    name = entry_name.get()
    roll_no = entry_roll_no.get()
    attendance = entry_attendance.get()
    print(f"{name} ({roll_no}): {attendance}")
    entry_name.delete(0, tk.END)
    entry_roll_no.delete(0, tk.END)
    entry_attendance.delete(0, tk.END)

button_submit = tk.Button(root, text="Submit", command=submit)

# Add the labels, entry boxes, and submit button to the main window
label_name.grid(row=0, column=0)
label_roll_no.grid(row=1, column=0)
label_attendance.grid(row=2, column=0)
entry_name.grid(row=0, column=1)
entry_roll_no.grid(row=1, column=1)
entry_attendance.grid(row=2, column=1)
button_submit.grid(row=3, column=1)

# Run the main loop
root.mainloop()

# %%
import tkinter as tk
import mysql.connector

# Connect to MySQL database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Create GUI
root = tk.Tk()
root.title("Student Attendance")

# Dropdown menu with options
options = ["IT", "CE"]
selected_option = tk.StringVar(value=options[0])
dropdown = tk.OptionMenu(root, selected_option, *options)
dropdown.pack()

# Function to fetch data from database and display in GUI
def display_students_table():
    # Clear previous data
    for widget in root.winfo_children():
        if widget not in [dropdown]:
            widget.destroy()
    
    # Fetch data from database
    cursor = mydb.cursor()
    if selected_option.get() == "IT":
        cursor.execute("SELECT name, roll FROM it_students")
    elif selected_option.get() == "CE":
        cursor.execute("SELECT name, roll FROM ce_students")
    data = cursor.fetchall()
    
    # Display data in GUI with tick marks
    for i, row in enumerate(data):
        name, roll = row
        label = tk.Label(root, text=f"{name} ({roll})")
        label.pack()
        tick_var = tk.BooleanVar(value=False)
        tickbox = tk.Checkbutton(root, variable=tick_var)
        tickbox.pack()
    
# Button to fetch data and display in GUI
button = tk.Button(root, text="Show Table", command=display_students_table)
button.pack()

root.mainloop()

# %%
import tkinter as tk
import mysql.connector
from tkinter import ttk

# Connect to MySQL database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Create GUI
root = tk.Tk()
root.title("Student Attendance")

# Dropdown menu with options
options = ["IT", "CE"]
selected_option = tk.StringVar(value=options[0])
dropdown = tk.OptionMenu(root, selected_option, *options)
dropdown.pack()

# Function to fetch data from database and display in GUI
def display_students_table():
    # Clear previous data
    for widget in root.winfo_children():
        if widget not in [dropdown]:
            widget.destroy()
    
    # Fetch data from database
    cursor = mydb.cursor()
    if selected_option.get() == "IT":
        cursor.execute("SELECT name, roll FROM it_students")
    elif selected_option.get() == "CE":
        cursor.execute("SELECT name, roll FROM ce_students")
    data = cursor.fetchall()
    
    # Display data in table format with tick marks
    table = ttk.Treeview(root, columns=('Name', 'Roll', 'Tick'))
    table.heading('Name', text='Name')
    table.heading('Roll', text='Roll')
    table.heading('Tick', text='Tick')
    table.column('#0', stretch=tk.NO, minwidth=0, width=0)
    table.column('#1', stretch=tk.YES, minwidth=0, width=200)
    table.column('#2', stretch=tk.YES, minwidth=0, width=200)
    table.column('#3', stretch=tk.YES, minwidth=0, width=100)
    
    for i, row in enumerate(data):
        name, roll = row
        table.insert(parent='', index='end', iid=i, values=(name, roll, ''))
    
    table.pack()
    
# Button to fetch data and display in GUI
button = tk.Button(root, text="Show Table", command=display_students_table)
button.pack()

root.mainloop()

# %%
 import tkinter as tk
import mysql.connector
from tkinter import ttk

# Connect to MySQL database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Create GUI
root = tk.Tk()
root.title("Student Attendance")

# Dropdown menu with options
options = ["IT", "CE"]
selected_option = tk.StringVar(value=options[0])
dropdown = tk.OptionMenu(root, selected_option, *options)
dropdown.pack()

def display_students_table():
    # Clear previous data
    for widget in root.winfo_children():
        if widget not in [dropdown]:
            widget.destroy()
    
    # Fetch data from database
    cursor = mydb.cursor()
    if selected_option.get() == "IT":
        cursor.execute("SELECT name, roll FROM it_students")
    elif selected_option.get() == "CE":
        cursor.execute("SELECT name, roll FROM ce_students")
    data = cursor.fetchall()
    
    # Display data in table format with tick marks
    table = ttk.Treeview(root, columns=('Name', 'Roll', 'Tick'))
    table.heading('Name', text='Name')
    table.heading('Roll', text='Roll')
    table.heading('Tick', text='Tick')
    table.column('#0', stretch=tk.NO, minwidth=0, width=0)
    table.column('#1', stretch=tk.YES, minwidth=0, width=200)
    table.column('#2', stretch=tk.YES, minwidth=0, width=200)
    table.column('#3', stretch=tk.YES, minwidth=0, width=100) # set width of third column
    
    # Define function to update attendance in database
    def update_attendance():
        for i, row in enumerate(data):
            name, roll = row
            tick = 'Absent' if not tick_vars[i].get() else 'Present'
            cursor.execute(f"INSERT INTO attendance (name, roll, attendance) VALUES ('{name}', '{roll}', '{tick}')")
        mydb.commit()
    
    # Add checkboxes for attendance
    tick_vars = []
    for i, row in enumerate(data):
        name, roll = row
        tick_var = tk.BooleanVar(value=True)
        tick_vars.append(tick_var)
        tick_button = tk.Checkbutton(table, variable=tick_var, onvalue=True, offvalue=False)
        table.insert(parent='', index='end', iid=i, values=(name, roll, tick_button), tags=i)
    
    table.pack()
    
    # Button to update attendance in database
    update_button = tk.Button(root, text="Update Attendance", command=update_attendance)
    update_button.pack()



# Button to fetch data and display in GUI
button = tk.Button(root, text="Show Table", command=display_students_table)
button.pack()

root.mainloop()

# %%
import tkinter as tk
import mysql.connector
from tkinter import ttk

# Connect to MySQL database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Create GUI
root = tk.Tk()
root.title("Student Attendance")

# Dropdown menu with options
options = ["IT", "CE"]
selected_option = tk.StringVar(value=options[0])
dropdown = tk.OptionMenu(root, selected_option, *options)
dropdown.pack()

def display_students_table():
    # Clear previous data
    for widget in root.winfo_children():
        if widget not in [dropdown]:
            widget.destroy()
    
    # Fetch data from database
    cursor = mydb.cursor()
    if selected_option.get() == "IT":
        cursor.execute("SELECT name, roll FROM it_students")
    elif selected_option.get() == "CE":
        cursor.execute("SELECT name, roll FROM ce_students")
    data = cursor.fetchall()
    
    # Display data in table format with tick marks
    table = ttk.Treeview(root, columns=('Name', 'Roll', 'Tick'))
    table.heading('Name', text='Name')
    table.heading('Roll', text='Roll')
    table.heading('Tick', text='Tick')
    table.column('#0', stretch=tk.NO, minwidth=0, width=0)
    table.column('#1', stretch=tk.YES, minwidth=0, width=200)
    table.column('#2', stretch=tk.YES, minwidth=0, width=200)
    table.column('#3', stretch=tk.YES, minwidth=0, width=100) # set width of third column
    
    # Define function to update attendance in database
    def update_attendance():
        for i, row in enumerate(data):
            name, roll = row
            tick = 'Absent' if not tick_vars[i].get() else 'Present'
            cursor.execute(f"INSERT INTO attendance (name, roll, attendance) VALUES ('{name}', '{roll}', '{tick}')")
        mydb.commit()
    
    # Add checkboxes for attendance
    tick_vars = []
    for i, row in enumerate(data):
        name, roll = row
        tick_var = tk.BooleanVar(value=True)
        tick_vars.append(tick_var)
        tick_button = ttk.Checkbutton(table, variable=tick_var, onvalue=True, offvalue=False)
        table.insert(parent='', index='end', iid=i, values=(name, roll, tick_button), tags=i)
        tick_button.state(['!alternate']) # remove focus border around the checkbox
    
    table.pack()
    
    # Button to update attendance in database
    update_button = tk.Button(root, text="Update Attendance", command=update_attendance)
    update_button.pack()



# Button to fetch data and display in GUI
button = tk.Button(root, text="Show Table", command=display_students_table)
button.pack()

root.mainloop()

# %%
import tkinter as tk
import mysql.connector

# Establishing connection with the database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Creating a cursor object
mycursor = mydb.cursor()

# Defining the function to display the student data with tick marks for attendance
def display_attendance(table_name):
    # Fetching the student data from the table
    mycursor.execute("SELECT * FROM " + table_name)
    student_data = mycursor.fetchall()

    # Creating a Tkinter window to display the student data
    window = tk.Toplevel(root)
    window.title(table_name + " Attendance")

    # Creating a table to display the student data with tick marks for attendance
    for i in range(len(student_data)):
        for j in range(len(student_data[0])):
            if j == 0:
                label = tk.Label(window, text=str(i+1))
                label.grid(row=i, column=j)
            else:
                label = tk.Label(window, text=str(student_data[i][j]))
                label.grid(row=i, column=j)

        attendance_var = tk.BooleanVar()
        attendance_var.set(False)
        attendance_checkbox = tk.Checkbutton(window, variable=attendance_var)
        attendance_checkbox.grid(row=i, column=j+1)

# Defining the function to handle the selection from the dropdown menu
def handle_dropdown(selection):
    if selection == "IT":
        display_attendance("it_students")
    elif selection == "CE":
        display_attendance("ce_students")

# Creating the Tkinter window
root = tk.Tk()
root.title("RKU Attendance")

# Creating the RKU label
rku_label = tk.Label(root, text="RK University")
rku_label.pack()

# Creating the dropdown menu for IT and CE
options = ["IT", "CE"]
dropdown_var = tk.StringVar(root)
dropdown_var.set(options[0])
dropdown_menu = tk.OptionMenu(root, dropdown_var, *options, command=handle_dropdown)
dropdown_menu.pack()

# Creating the submit button
submit_button = tk.Button(root, text="Submit Attendance")
submit_button.pack()

# Starting the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
import mysql.connector

# Establishing connection with the database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Creating a cursor object
mycursor = mydb.cursor()

# Defining the function to display the student data with tick marks for attendance
def display_attendance(table_name):
    # Fetching the student data from the table
    mycursor.execute("SELECT * FROM " + table_name)
    student_data = mycursor.fetchall()

    # Clearing the previous data from the frame
    for widget in frame.winfo_children():
        widget.destroy()

    # Creating the table headers
    headers = ["Roll No.", "Name", "Attendance"]
    for j, header in enumerate(headers):
        label = tk.Label(frame, text=header)
        label.grid(row=0, column=j)

    # Creating a table to display the student data with tick marks for attendance
    for i in range(len(student_data)):
        # Displaying the roll number
        label = tk.Label(frame, text=str(student_data[i][0]))
        label.grid(row=i+1, column=0)

        # Displaying the name
        label = tk.Label(frame, text=str(student_data[i][1]))
        label.grid(row=i+1, column=1)

        attendance_var = tk.BooleanVar()
        attendance_var.set(False)
        attendance_checkbox = tk.Checkbutton(frame, variable=attendance_var)
        attendance_checkbox.grid(row=i+1, column=2)
 

# Defining the function to handle the selection from the dropdown menu
def handle_dropdown(selection):
    if selection == "IT":
        display_attendance("it_students")
    elif selection == "CE":
        display_attendance("ce_students")

# Creating the Tkinter window
root = tk.Tk()
root.title("RKU Attendance")
root.geometry("500x400")

# Adding the RKU server label
rku_server_label = tk.Label(root, text="Welcome to RKU Server",font=("Arial", 20))
rku_server_label.pack()


faculty_frame = tk.Frame(root)
faculty_frame.pack()
faculty_label = tk.Label(faculty_frame, text="Faculty:")
faculty_label.pack(side="left", anchor="w")
faculty_entry = tk.Entry(faculty_frame)
faculty_entry.pack(side="left")

# Creating the Date label and entry
date_frame = tk.Frame(root)
date_frame.pack()
date_label = tk.Label(date_frame, text="Date:")
date_label.pack(side="left", anchor="w")
date_entry = tk.Entry(date_frame)
date_entry.pack(side="left")







# Creating a frame for the label and dropdown menu
dropdown_frame = tk.Frame(root)
dropdown_frame.pack()

# Creating the label for the dropdown menu
division_label = tk.Label(dropdown_frame, text="Division:")
division_label.pack(side="left", anchor="w")

# Creating the dropdown menu for IT and CE
options = ["IT", "CE"]
dropdown_var = tk.StringVar(root)
dropdown_var.set(options[0])
dropdown_menu = tk.OptionMenu(dropdown_frame, dropdown_var, *options, command=handle_dropdown)
dropdown_menu.pack(side="left")

 

# Creating a frame to display the data
frame = tk.Frame(root)
frame.pack()

# Creating the submit button
submit_button = tk.Button(root, text="Submit Attendance")
submit_button.pack()

# Starting the Tkinter main loop
root.mainloop()

# %%
 import tkinter as tk
import mysql.connector

# Establishing connection with the database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Creating a cursor object
mycursor = mydb.cursor()

# Defining the function to display the student data with tick marks for attendance
def display_attendance(table_name):
    # Fetching the student data from the table
    mycursor.execute("SELECT * FROM " + table_name)
    student_data = mycursor.fetchall()

    # Clearing the previous data from the frame
    for widget in frame.winfo_children():
        widget.destroy()

    # Creating the table headers
    headers = ["Roll No.", "Name", "Attendance"]
    for j, header in enumerate(headers):
        label = tk.Label(frame, text=header)
        label.grid(row=0, column=j)

    # Creating a table to display the student data with tick marks for attendance
    for i in range(len(student_data)):
        # Displaying the roll number
        label = tk.Label(frame, text=str(student_data[i][0]))
        label.grid(row=i+1, column=0)

        # Displaying the name
        label = tk.Label(frame, text=str(student_data[i][1]))
        label.grid(row=i+1, column=1)

        attendance_var = tk.BooleanVar()
        attendance_var.set(False)
        attendance_checkbox = tk.Checkbutton(frame, variable=attendance_var)
        attendance_checkbox.grid(row=i+1, column=2)

# Defining the function to handle the submission of attendance data
def submit_attendance():
    # Getting the faculty, division, and date
    faculty = faculty_entry.get()
    division = dropdown_var.get()
    date = date_entry.get()

    # Fetching the student data from the database
    mycursor.execute("SELECT * FROM " + division.lower() + "_students")
    student_data = mycursor.fetchall()

    # Creating a list to store the attendance data
    attendance_data = []

    # Looping through the student data to get the attendance status for each student
    for i in range(len(student_data)):
        student_name = student_data[i][1]
        attendance_status = int(attendance_vars[i].get())
        attendance_data.append((faculty, division, date, student_name, attendance_status))

    # Inserting the attendance data into the database
    mycursor.executemany("INSERT INTO attendance (faculty, division, date, student_name, attendance_status) VALUES (%s, %s, %s, %s, %s)", attendance_data)
    mydb.commit()

# Defining the function to handle the selection from the dropdown menu
def handle_dropdown(selection):
    if selection == "IT":
        display_attendance("it_students")
    elif selection == "CE":
        display_attendance("ce_students")

# Creating the Tkinter window
root = tk.Tk()
root.title("RKU Attendance")
root.geometry("500x400")

# Adding the RKU server label
rku_server_label = tk.Label(root, text="Welcome to RKU Server",font=("Arial", 20))
rku_server_label.pack()

faculty_frame = tk.Frame(root)
faculty_frame.pack()
faculty_label = tk.Label(faculty_frame, text="Faculty:")
faculty_label.pack(side="left", anchor="w")
faculty_entry = tk.Entry(faculty_frame)
faculty_entry.pack(side="left")

# Creating the Date label and entry
date_frame = tk.Frame(root)
date_frame.pack()
date_label = tk.Label(date_frame, text="Date:")
date_label.pack(side="left", anchor="w")
date_entry = tk.Entry(date_frame)
date_entry.pack(side="left")







# Creating a frame for the label and dropdown menu
dropdown_frame = tk.Frame(root)
dropdown_frame.pack()

# Creating the label for the dropdown menu
division_label = tk.Label(dropdown_frame, text="Division:")
division_label.pack(side="left", anchor="w")

# Creating the dropdown menu for IT and CE
options = ["IT", "CE"]
dropdown_var = tk.StringVar(root)
dropdown_var.set(options[0])
dropdown_menu = tk.OptionMenu(dropdown_frame, dropdown_var, *options, command=handle_dropdown)
dropdown_menu.pack(side="left")

 

# Creating a frame to display the data
frame = tk.Frame(root)
frame.pack()

# Creating the submit button
submit_button = tk.Button(root, text="Submit Attendance")
submit_button.pack()

# Creating the submit button
submit_button = tk.Button(root, text="Submit Attendance", command=submit_attendance)
submit_button.pack()


# Starting the Tkinter main loop
root.mainloop()

# %%
 import tkinter as tk
import mysql.connector
from tkinter import messagebox


# Establishing connection with the database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Creating a cursor object
mycursor = mydb.cursor()

# Defining the function to display the student data with tick marks for attendance
def display_attendance(table_name):
    # Fetching the student data from the table
    mycursor.execute("SELECT * FROM " + table_name)
    student_data = mycursor.fetchall()

    # Clearing the previous data from the frame
    for widget in frame.winfo_children():
        widget.destroy()

    # Creating the table headers
    headers = ["Roll No.", "Name", "Attendance"]
    for j, header in enumerate(headers):
        label = tk.Label(frame, text=header)
        label.grid(row=0, column=j)

    # Creating a table to display the student data with tick marks for attendance
    for i in range(len(student_data)):
        # Displaying the roll number
        label = tk.Label(frame, text=str(student_data[i][0]))
        label.grid(row=i+1, column=0)

        # Displaying the name
        label = tk.Label(frame, text=str(student_data[i][1]))
        label.grid(row=i+1, column=1)

        attendance_var = tk.BooleanVar()
        attendance_var.set(False)
        attendance_checkbox = tk.Checkbutton(frame, variable=attendance_var)
        attendance_checkbox.grid(row=i+1, column=2)

# Defining the function to handle the submission of attendance data
def submit_attendance():
    # Getting the faculty, division, and date
    faculty = faculty_entry.get()
    division = dropdown_var.get()
    date = date_entry.get()

    # Fetching the student data from the database
    mycursor.execute("SELECT * FROM " + division.lower() + "_students")
    student_data = mycursor.fetchall()

    # Creating a list to store the attendance data
    attendance_data = []


    # Creating a list of BooleanVar() variables for attendance status
    attendance_vars = [tk.BooleanVar() for i in range(len(student_data))]

    # Looping through the student data to get the attendance status for each student
    for i in range(len(student_data)):
        student_name = student_data[i][1]
        attendance_status = int(attendance_vars[i].get())
        attendance_data.append((faculty, division, date, student_name, attendance_status))

    # Inserting the attendance data into the database
    mycursor.executemany("INSERT INTO attendance (faculty, division, date, student_name, attendance_status) VALUES (%s, %s, %s, %s, %s)", attendance_data)
    mydb.commit()

    # Displaying a message box after successfully adding attendance data
    messagebox.showinfo("Success", "Attendance added successfully!")


# Defining the function to handle the selection from the dropdown menu
def handle_dropdown(selection):
    if selection == "IT":
        display_attendance("it_students")
    elif selection == "CE":
        display_attendance("ce_students")

# Creating the Tkinter window
root = tk.Tk()
root.title("RKU Attendance")
root.geometry("500x400")

# Adding the RKU server label
rku_server_label = tk.Label(root, text="Welcome to RKU Server",font=("Arial", 20))
rku_server_label.pack()

faculty_frame = tk.Frame(root)
faculty_frame.pack()
faculty_label = tk.Label(faculty_frame, text="Faculty:")
faculty_label.pack(side="left", anchor="w")
faculty_entry = tk.Entry(faculty_frame)
faculty_entry.pack(side="left")

# Creating the Date label and entry
date_frame = tk.Frame(root)
date_frame.pack()
date_label = tk.Label(date_frame, text="Date:")
date_label.pack(side="left", anchor="w")
date_entry = tk.Entry(date_frame)
date_entry.pack(side="left")







# Creating a frame for the label and dropdown menu
dropdown_frame = tk.Frame(root)
dropdown_frame.pack()

# Creating the label for the dropdown menu
division_label = tk.Label(dropdown_frame, text="Division:")
division_label.pack(side="left", anchor="w")

# Creating the dropdown menu for IT and CE
options = ["IT", "CE"]
dropdown_var = tk.StringVar(root)
dropdown_var.set(options[0])
dropdown_menu = tk.OptionMenu(dropdown_frame, dropdown_var, *options, command=handle_dropdown)
dropdown_menu.pack(side="left")

 

# Creating a frame to display the data
frame = tk.Frame(root)
frame.pack()

 

# Creating the submit button
submit_button = tk.Button(root, text="Submit Attendance", command=submit_attendance)
submit_button.pack()


# Starting the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
import mysql.connector
from tkinter import messagebox


# Establishing connection with the database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rku_attendence_admin"
)

# Creating a cursor object
mycursor = mydb.cursor()

# Defining the function to display the student data with tick marks for attendance
def display_attendance(table_name):
    # Fetching the student data from the table
    mycursor.execute("SELECT * FROM " + table_name)
    student_data = mycursor.fetchall()

    # Clearing the previous data from the frame
    for widget in frame.winfo_children():
        widget.destroy()

    # Creating the table headers
    headers = ["Roll No.", "Name", "Attendance"]
    for j, header in enumerate(headers):
        label = tk.Label(frame, text=header)
        label.grid(row=0, column=j)

    # Creating a table to display the student data with tick marks for attendance
    attendance_vars = []
    for i in range(len(student_data)):
        # Displaying the roll number
        label = tk.Label(frame, text=str(student_data[i][0]))
        label.grid(row=i+1, column=0)

        # Displaying the name
        label = tk.Label(frame, text=str(student_data[i][1]))
        label.grid(row=i+1, column=1)

        attendance_var = tk.BooleanVar()
        attendance_var.set(False)
        attendance_vars.append(attendance_var)
        attendance_checkbox = tk.Checkbutton(frame, variable=attendance_var)
        attendance_checkbox.grid(row=i+1, column=2)

    # Return the attendance_vars and student_data
    return attendance_vars, student_data

# Defining the function to handle the submission of attendance data
def submit_attendance():
    # Getting the faculty, division, and date
    faculty = faculty_entry.get()
    division = dropdown_var.get()
    date = date_entry.get()

    # Fetching the student data from the database
    mycursor.execute("SELECT * FROM " + division.lower() + "_students")
    student_data = mycursor.fetchall()

    # Displaying the attendance data with tick marks
    attendance_vars, student_data = display_attendance(division.lower() + "_students")

    # Creating a list to store the attendance data
    attendance_data = []

    # Get the attendance status for each student
    for i in range(len(student_data)):
        student_name = student_data[i][1]
        attendance_status = attendance_vars[i].get()
        attendance_data.append((faculty, division, date, student_name, attendance_status))

        # Update the attendance status of the student in the database
        mycursor.execute("UPDATE " + division.lower() + "_students SET attendance_status=%s WHERE name=%s", (attendance_status, student_name))

    # Inserting the attendance data into the database
    mycursor.executemany("INSERT INTO attendance (faculty, division, date, student_name, attendance_status) VALUES (%s, %s, %s, %s, %s)", attendance_data)
    mydb.commit()

    # Displaying a message box after successfully adding attendance
 
    # Displaying a message box after successfully adding attendance data
    messagebox.showinfo("Success", "Attendance added successfully!")


    

# Defining the function to handle the selection from the dropdown menu
def handle_dropdown(selection):
    if selection == "IT":
        display_attendance("it_students")
    elif selection == "CE":
        display_attendance("ce_students")

# Creating the Tkinter window
root = tk.Tk()
root.title("RKU Attendance")
root.geometry("500x400")

# Adding the RKU server label
rku_server_label = tk.Label(root, text="Welcome to RKU Server",font=("Arial", 20))
rku_server_label.pack()

faculty_frame = tk.Frame(root)
faculty_frame.pack()
faculty_label = tk.Label(faculty_frame, text="Faculty:")
faculty_label.pack(side="left", anchor="w")
faculty_entry = tk.Entry(faculty_frame)
faculty_entry.pack(side="left")

# Creating the Date label and entry
date_frame = tk.Frame(root)
date_frame.pack()
date_label = tk.Label(date_frame, text="Date:")
date_label.pack(side="left", anchor="w")
date_entry = tk.Entry(date_frame)
date_entry.pack(side="left")



# Creating a frame for the label and dropdown menu
dropdown_frame = tk.Frame(root)
dropdown_frame.pack()

# Creating the label for the dropdown menu
division_label = tk.Label(dropdown_frame, text="Division:")
division_label.pack(side="left", anchor="w")

# Creating the dropdown menu for IT and CE
options = ["IT", "CE"]
dropdown_var = tk.StringVar(root)
dropdown_var.set(options[0])
dropdown_menu = tk.OptionMenu(dropdown_frame, dropdown_var, *options, command=handle_dropdown)
dropdown_menu.pack(side="left")

 

# Creating a frame to display the data
frame = tk.Frame(root)
frame.pack()

 

# Creating the submit button
submit_button = tk.Button(root, text="Submit Attendance", command=submit_attendance)
submit_button.pack()


# Starting the Tkinter main loop
root.mainloop()
